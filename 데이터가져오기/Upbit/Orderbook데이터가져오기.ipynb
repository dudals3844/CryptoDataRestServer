# %%
import pymongo
from pymongo import MongoClient
import pickle
from numba import jit
import numpy as np

# %%
MONGO_HOST = 'mongodb://choi:3844@youngminhome.iptime.org:27017/'

# %%
mongo_client = MongoClient(MONGO_HOST, port=27017)

# %%
upbit = mongo_client['Upbit']

# %%
orderbook_collection = upbit['orderbook']

# %%
ticker = 'KRW-SAND'

# %%
orderbook_dicts = list(orderbook_collection.find({}))

# %%
orderbook_dicts
# Out:
# [{'_id': ObjectId('622df19efc5e1031cc02c981'),
#   'market': 'KRW-SAND',
#   'timestamp': 1647178142676,
#   'total_ask_size': 527697.02277542,
#   'total_bid_size': 862048.70445319,
#   'orderbook_units': [{'ask_price': 3500.0,
#     'bid_price': 3495.0,
#     'ask_size': 28618.9262074,
#     'bid_size': 10675.77411554},
#    {'ask_price': 3505.0,
#     'bid_price': 3490.0,
#     'ask_size': 54916.11144869,
#     'bid_size': 59193.4295707},
#    {'ask_price': 3510.0,
#     'bid_price': 3485.0,
#     'ask_size': 80184.79628688,
#     'bid_size': 20677.80907815},
#    {'ask_price': 3515.0,
#     'bid_price': 3480.0,
#     'ask_size': 179187.09028365,
#     'bid_size': 50670.85788201},
#    {'ask_price': 3520.0,
#     'bid_price': 3475.0,
#     'ask_size': 8561.93933546,
#     'bid_size': 31570.20436778},
#    {'ask_price': 3525.0,
#     'bid_price': 3470.0,
#     'ask_size': 50827.50787232,
#     'bid_size': 58544.3046449},
#    {'ask_price': 3530.0,
#     'bid_price': 3465.0,
# ...

# %%
type(orderbook_dicts)
# Out:
# list

# %%
with open('orderbook.pickle', 'wb') as fw:
    pickle.dump(orderbook_dicts, fw)

# %%
tmp = orderbook_dicts[0]

# %%
sand_orderbooks = list(filter(lambda x: x['market']=='KRW-SAND', orderbook_dicts))

# %%
tmp = sand_orderbooks[0]

# %%
for a in tmp['orderbook_units']:
    print(a)
# Out:
# {'ask_price': 3500.0, 'bid_price': 3495.0, 'ask_size': 28618.9262074, 'bid_size': 10675.77411554}
# {'ask_price': 3505.0, 'bid_price': 3490.0, 'ask_size': 54916.11144869, 'bid_size': 59193.4295707}
# {'ask_price': 3510.0, 'bid_price': 3485.0, 'ask_size': 80184.79628688, 'bid_size': 20677.80907815}
# {'ask_price': 3515.0, 'bid_price': 3480.0, 'ask_size': 179187.09028365, 'bid_size': 50670.85788201}
# {'ask_price': 3520.0, 'bid_price': 3475.0, 'ask_size': 8561.93933546, 'bid_size': 31570.20436778}
# {'ask_price': 3525.0, 'bid_price': 3470.0, 'ask_size': 50827.50787232, 'bid_size': 58544.3046449}
# {'ask_price': 3530.0, 'bid_price': 3465.0, 'ask_size': 7482.46603921, 'bid_size': 69310.25701136}
# {'ask_price': 3535.0, 'bid_price': 3460.0, 'ask_size': 10540.2500401, 'bid_size': 170926.55551207}
# {'ask_price': 3540.0, 'bid_price': 3455.0, 'ask_size': 35429.55054066, 'bid_size': 48846.32343993}
# ...
